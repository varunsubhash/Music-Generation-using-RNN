# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  3.273366  0.160753
# 1       2  2.418410  0.326296
# 2       3  1.851005  0.462751
# 3       4  1.610977  0.522205
# 4       5  1.483030  0.544697
# ..    ...       ...       ...
# 95     96  0.221657  0.925316
# 96     97  0.221685  0.925494
# 97     98  0.218644  0.926556
# 98     99  0.214792  0.927316
# 99    100  0.212119  0.928548
#
# [100 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
